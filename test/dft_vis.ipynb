# %%
import numpy as np
import matplotlib.pyplot as plt
import peakutils
# %matplotlib notebook

# %%
pltx = []
plty = []

fx = []
fy = []

# %%
with open("../data/square.csv", "r") as f:
    del plty[:]
    
    i = 0
    for line in f:
        i += 1
        if i < 3:
            continue
            
        line = line.split(",")
        plty.append(float(line[1]))
        
    plt.figure()
    plt.plot(plty)
    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
with open("dft.txt", "r") as f:
    del fy[:]
    i = 0
    for line in f:
        if True:
        #if i % 2 == 0:
            line = line.split(",")
            fy.append(float(line[1]))
        i += 1
    
    print(len(fy))

    nfy = np.array(fy)
    indexes = peakutils.indexes(nfy, thres=5*10e3/max(nfy), min_dist=1)
    peak_coords_y = []
    for i in range(len(indexes)):
        peak_coords_y.append(fy[indexes[i]])
    
    plt.figure()
    plt.title("Frequency Spectrum")
    plt.xlabel("Hz")
    plt.ylabel("Magnitude")
    plt.yscale('log')
    plt.plot(fy[:len(fy)//2], label="dft(x)")
    
    exp_f = [1, 5, 20, 100, 200]
    for ef in exp_f:
        #plt.axvline(ef, color='r')
        pass
    
    plt.scatter(indexes, peak_coords_y, marker='x', color='r', label="Peaks")
    
    plt.legend()
    plt.grid()
    plt.show()
# Out:
# 1001
# <img src="data:image/png;base64,..." width="660">
